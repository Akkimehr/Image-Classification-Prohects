# %%
import pandas as pd
import numpy as np 
from tensorflow.keras.layers import Conv2D, Flatten, MaxPool2D, Dense, ZeroPadding2D, Input, Activation, BatchNormalization, Add, GlobalAveragePooling2D
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
from tensorflow.keras.datasets import mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (60000, 28, 28) (10000, 28, 28) (60000,) (10000,)

# %%
np.random.seed(123)

# %%
#### RESHAPING THE TRAIN AND TEST DATA ACCORDING TO THE MODELS REQUIREMENT

X_train = X_train.reshape([-1, 28, 28, 1]).astype('float32')
X_test = X_test.reshape([-1, 28, 28, 1]).astype('float32')

X_train = X_train/255
X_train = X_train

X_test = X_test/255

# %%
#### PRINTING THE TRAINING AND TEST LABELS ACCORDING TO THE MODELS REQUIREMENT

from tensorflow.keras.utils import to_categorical

Y_train_cm = Y_train
Y_test_cm = Y_test

Y_train_req = to_categorical(Y_train)
Y_test_req = to_categorical(Y_test)

print(Y_train_cm.shape, Y_test_cm.shape, Y_train_req.shape, Y_test_req.shape)
# Out:
# (60000,) (10000,) (60000, 10) (10000, 10)

# %% [markdown]
# <h1>LENET-5 FOR MNIST DATA</h1>

# %%
#### CREATING THE MODEL : LENET-5

model = Sequential()
model.add(Conv2D(6, (5,5), strides=1, input_shape=(28,28,1), activation='relu'))
model.add(MaxPool2D((2,2), strides=2))
model.add(Conv2D(16, (5,5), strides=1, activation='relu'))
model.add(MaxPool2D((2,2), strides=2))
model.add(Flatten())
model.add(Dense(120, activation='relu'))
model.add(Dense(84, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
#### PRINTING THE MODEL SUMMARY

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 24, 24, 6)         156
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 8, 8, 16)          2416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               30840
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %%
#### COMPILING THE MODEL

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#### FITTING THE MDOEL

model.fit(X_train, Y_train_req, validation_split=0.1, epochs=15, batch_size=32)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/15
# 54000/54000 [==============================] - 18s 328us/sample - loss: 0.2010 - accuracy: 0.9370 - val_loss: 0.0731 - val_accuracy: 0.9783
# Epoch 2/15
# 54000/54000 [==============================] - 15s 270us/sample - loss: 0.0711 - accuracy: 0.9777 - val_loss: 0.0473 - val_accuracy: 0.9857
# Epoch 3/15
# 54000/54000 [==============================] - 16s 294us/sample - loss: 0.0508 - accuracy: 0.9840 - val_loss: 0.0457 - val_accuracy: 0.9870
# Epoch 4/15
# 54000/54000 [==============================] - 16s 294us/sample - loss: 0.0387 - accuracy: 0.9877 - val_loss: 0.0533 - val_accuracy: 0.9843
# Epoch 5/15
# 54000/54000 [==============================] - 17s 306us/sample - loss: 0.0306 - accuracy: 0.9902 - val_loss: 0.0437 - val_accuracy: 0.9872
# Epoch 6/15
# 54000/54000 [==============================] - 17s 307us/sample - loss: 0.0267 - accuracy: 0.9914 - val_loss: 0.0393 - val_accuracy: 0.9895
# Epoch 7/15
# 54000/54000 [==============================] - 17s 319us/sample - loss: 0.0219 - accuracy: 0.9929 - val_loss: 0.0514 - val_accuracy: 0.9857
# Epoch 8/15
# 54000/54000 [==============================] - 17s 309us/sample - loss: 0.0195 - accuracy: 0.9936 - val_loss: 0.0438 - val_accuracy: 0.9887
# Epoch 9/15
# 54000/54000 [==============================] - 16s 304us/sample - loss: 0.0176 - accuracy: 0.9941 - val_loss: 0.0406 - val_accuracy: 0.9905
# Epoch 10/15
# 54000/54000 [==============================] - 17s 312us/sample - loss: 0.0153 - accuracy: 0.9950 - val_loss: 0.0372 - val_accuracy: 0.9900
# Epoch 11/15
# 54000/54000 [==============================] - 18s 341us/sample - loss: 0.0144 - accuracy: 0.9951 - val_loss: 0.0450 - val_accuracy: 0.9892
# Epoch 12/15
# 54000/54000 [==============================] - 17s 313us/sample - loss: 0.0127 - accuracy: 0.9957 - val_loss: 0.0486 - val_accuracy: 0.9898
# Epoch 13/15
# 54000/54000 [==============================] - 17s 308us/sample - loss: 0.0110 - accuracy: 0.9965 - val_loss: 0.0464 - val_accuracy: 0.9902
# Epoch 14/15
# 54000/54000 [==============================] - 17s 314us/sample - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0548 - val_accuracy: 0.9897
# Epoch 15/15
# 54000/54000 [==============================] - 17s 322us/sample - loss: 0.0091 - accuracy: 0.9968 - val_loss: 0.0574 - val_accuracy: 0.9887

# %%
#### EVALUATING THE LENET-5 MODEL FOR MNIST DATA

model.evaluate(X_test, Y_test_req, batch_size=32)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.05281400087490454, 0.9882]

# %%
#### PRINTING THE CONFUSION MATRIX

predictions = model.predict_classes(X_test)
print(confusion_matrix(Y_test_cm, predictions))
# Out:
# [[ 974    1    0    0    0    0    0    2    3    0]
#  [   2 1127    1    1    0    0    1    1    2    0]
#  [   1    4 1018    2    1    0    0    2    4    0]
#  [   0    0    1 1005    0    2    0    0    2    0]
#  [   0    1    0    0  972    0    2    2    0    5]
#  [   0    0    0   19    0  866    1    1    2    3]
#  [   3    3    0    0    1    2  947    0    2    0]
#  [   0    4    2    0    2    0    0 1018    1    1]
#  [   2    0    1    2    1    0    2    1  963    2]
#  [   0    0    0    2    5    4    1    0    5  992]]

# %% [markdown]
# <h1>ALEX NET </h1>

# %%
#### CREATING THE ALEXNET MODEL

model = Sequential()
model.add(Conv2D(96, (3,3), strides=1, input_shape=(28,28,1), activation='relu'))
model.add(MaxPool2D((3,3), strides=2))
model.add(Conv2D(256, (5,5), padding='same', activation='relu'))
model.add(MaxPool2D((3,3), strides=2))
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(384, (3,3), padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), padding='same', activation='relu'))
model.add(MaxPool2D((3,3), strides=2))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dense(4096, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
#### PRINTING THE MODEL SUMMARY

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 26, 26, 96)        960
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 96)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 256)       614656
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 5, 5, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 5, 5, 384)         885120
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 5, 5, 384)         1327488
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 256)         884992
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              4198400
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 10)                40970
# =================================================================
# Total params: 24,733,898
# Trainable params: 24,733,898
# Non-trainable params: 0
# _________________________________________________________________

# %%
#### COMPILING THE MODEL

opt = SGD(lr=1e-4, momentum=0.9)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
#### FITTING THE MODEL

model.fit(X_train, Y_train_req, validation_split=0.1, epochs=20, batch_size=32)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/20
# 54000/54000 [==============================] - 199s 4ms/sample - loss: 2.2928 - accuracy: 0.2882 - val_loss: 2.2809 - val_accuracy: 0.4378
# Epoch 2/20
# 54000/54000 [==============================] - 232s 4ms/sample - loss: 2.2469 - accuracy: 0.5063 - val_loss: 2.1670 - val_accuracy: 0.6157
# Epoch 3/20
# 54000/54000 [==============================] - 223s 4ms/sample - loss: 1.4418 - accuracy: 0.6910 - val_loss: 0.5845 - val_accuracy: 0.8220
# Epoch 4/20
# 54000/54000 [==============================] - 224s 4ms/sample - loss: 0.4279 - accuracy: 0.8735 - val_loss: 0.2455 - val_accuracy: 0.9295
# Epoch 5/20
# 54000/54000 [==============================] - 234s 4ms/sample - loss: 0.2487 - accuracy: 0.9234 - val_loss: 0.1787 - val_accuracy: 0.9468
# Epoch 6/20
# 54000/54000 [==============================] - 242s 4ms/sample - loss: 0.1882 - accuracy: 0.9424 - val_loss: 0.1416 - val_accuracy: 0.9567
# Epoch 7/20
# 54000/54000 [==============================] - 239s 4ms/sample - loss: 0.1554 - accuracy: 0.9507 - val_loss: 0.1377 - val_accuracy: 0.9582
# Epoch 8/20
# 54000/54000 [==============================] - 233s 4ms/sample - loss: 0.1357 - accuracy: 0.9582 - val_loss: 0.1336 - val_accuracy: 0.9605
# Epoch 9/20
# 54000/54000 [==============================] - 184s 3ms/sample - loss: 0.1227 - accuracy: 0.9619 - val_loss: 0.1086 - val_accuracy: 0.9692
# Epoch 10/20
# 54000/54000 [==============================] - 182s 3ms/sample - loss: 0.1092 - accuracy: 0.9657 - val_loss: 0.0953 - val_accuracy: 0.9725
# Epoch 11/20
# 54000/54000 [==============================] - 192s 4ms/sample - loss: 0.1005 - accuracy: 0.9681 - val_loss: 0.0802 - val_accuracy: 0.9770
# Epoch 12/20
# 54000/54000 [==============================] - 203s 4ms/sample - loss: 0.0921 - accuracy: 0.9707 - val_loss: 0.0827 - val_accuracy: 0.9758
# Epoch 13/20
# 54000/54000 [==============================] - 204s 4ms/sample - loss: 0.0868 - accuracy: 0.9725 - val_loss: 0.0761 - val_accuracy: 0.9775
# Epoch 14/20
# 54000/54000 [==============================] - 205s 4ms/sample - loss: 0.0807 - accuracy: 0.9755 - val_loss: 0.0759 - val_accuracy: 0.9780
# Epoch 15/20
# 54000/54000 [==============================] - 205s 4ms/sample - loss: 0.0751 - accuracy: 0.9760 - val_loss: 0.0683 - val_accuracy: 0.9795
# Epoch 16/20
# 54000/54000 [==============================] - 205s 4ms/sample - loss: 0.0727 - accuracy: 0.9776 - val_loss: 0.0619 - val_accuracy: 0.9813
# Epoch 17/20
# 54000/54000 [==============================] - 218s 4ms/sample - loss: 0.0674 - accuracy: 0.9794 - val_loss: 0.0763 - val_accuracy: 0.9775
# Epoch 18/20
# 54000/54000 [==============================] - 222s 4ms/sample - loss: 0.0642 - accuracy: 0.9802 - val_loss: 0.0638 - val_accuracy: 0.9817
# Epoch 19/20
# 54000/54000 [==============================] - 222s 4ms/sample - loss: 0.0604 - accuracy: 0.9814 - val_loss: 0.0575 - val_accuracy: 0.9832
# Epoch 20/20
# 54000/54000 [==============================] - 229s 4ms/sample - loss: 0.0581 - accuracy: 0.9818 - val_loss: 0.0564 - val_accuracy: 0.9837

# %%
#### EVALUATING THE MODEL

model.evaluate(X_test, Y_test_req, batch_size=32)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.04592741938894614, 0.9857]

# %%
#### PRINTING THE CONFUSION MATRIX

predictions = model.predict_classes(X_test)
print(confusion_matrix(Y_test_cm, predictions))
# Out:
# [[ 968    0    2    0    1    0    2    2    4    1]
#  [   0 1131    2    0    0    0    0    2    0    0]
#  [   1    2 1024    0    0    0    0    4    1    0]
#  [   0    0    3  988    0    4    0    5    9    1]
#  [   0    0    0    0  972    0    1    3    2    4]
#  [   3    0    0    6    0  871    5    1    4    2]
#  [   4    3    0    1    3    1  942    0    4    0]
#  [   0    1    8    0    0    0    0 1017    2    0]
#  [   4    0    4    1    0    1    0    3  958    3]
#  [   3    3    0    3    5    1    0    7    1  986]]

# %% [markdown]
# <h1> VGG-16 LIKE MODEL </h1>

# %%
model = Sequential()
model.add(Input((28, 28, 1)))
model.add(ZeroPadding2D((2,2)))
model.add(Conv2D(64, (3,3), strides=1, padding='same', activation='relu'))
model.add(Conv2D(64, (3,3), strides=1, padding='same', activation='relu'))
model.add(MaxPool2D((2,2), strides=2))
model.add(Conv2D(128, (3,3), strides=1, padding='same', activation='relu'))
model.add(Conv2D(128, (3,3), strides=1, padding='same', activation='relu'))
model.add(MaxPool2D((2,2), strides=2))
model.add(Conv2D(256, (3,3), strides=1, padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), strides=1, padding='same', activation='relu'))
model.add(Conv2D(256, (3,3), strides=1, padding='same', activation='relu'))
model.add(MaxPool2D((2,2), strides=2))
model.add(Flatten())
model.add(Dense(4096, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# zero_padding2d (ZeroPadding2 (None, 32, 32, 1)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 32, 32, 64)        640
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 8, 8, 256)         295168
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 8, 8, 256)         590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               524416
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 19,041,354
# Trainable params: 19,041,354
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = SGD(lr=1e-4, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
model.fit(X_train, Y_train_req, epochs=30, batch_size=32, validation_split=0.1)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/30
# 54000/54000 [==============================] - 197s 4ms/sample - loss: 2.2973 - accuracy: 0.1411 - val_loss: 2.2922 - val_accuracy: 0.1088
# Epoch 2/30
# 54000/54000 [==============================] - 198s 4ms/sample - loss: 2.2826 - accuracy: 0.2839 - val_loss: 2.2658 - val_accuracy: 0.4530
# Epoch 3/30
# 54000/54000 [==============================] - 195s 4ms/sample - loss: 2.0303 - accuracy: 0.5290 - val_loss: 0.7658 - val_accuracy: 0.7920
# Epoch 4/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.4642 - accuracy: 0.8550 - val_loss: 0.2350 - val_accuracy: 0.9317
# Epoch 5/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.2411 - accuracy: 0.9237 - val_loss: 0.1700 - val_accuracy: 0.9457
# Epoch 6/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.1692 - accuracy: 0.9470 - val_loss: 0.1292 - val_accuracy: 0.9633
# Epoch 7/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.1351 - accuracy: 0.9573 - val_loss: 0.1123 - val_accuracy: 0.9678
# Epoch 8/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.1118 - accuracy: 0.9640 - val_loss: 0.0870 - val_accuracy: 0.9768
# Epoch 9/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.0958 - accuracy: 0.9697 - val_loss: 0.0816 - val_accuracy: 0.9760
# Epoch 10/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.0838 - accuracy: 0.9740 - val_loss: 0.0729 - val_accuracy: 0.9800
# Epoch 11/30
# 54000/54000 [==============================] - 196s 4ms/sample - loss: 0.0750 - accuracy: 0.9768 - val_loss: 0.0693 - val_accuracy: 0.9802
# Epoch 12/30
# 54000/54000 [==============================] - 200s 4ms/sample - loss: 0.0672 - accuracy: 0.9785 - val_loss: 0.0697 - val_accuracy: 0.9795
# Epoch 13/30
# 54000/54000 [==============================] - 208s 4ms/sample - loss: 0.0619 - accuracy: 0.9802 - val_loss: 0.0693 - val_accuracy: 0.9798
# Epoch 14/30
# 54000/54000 [==============================] - 219s 4ms/sample - loss: 0.0566 - accuracy: 0.9819 - val_loss: 0.0629 - val_accuracy: 0.9823
# Epoch 15/30
# 54000/54000 [==============================] - 214s 4ms/sample - loss: 0.0526 - accuracy: 0.9837 - val_loss: 0.0616 - val_accuracy: 0.9823
# Epoch 16/30
# 54000/54000 [==============================] - 215s 4ms/sample - loss: 0.0470 - accuracy: 0.9849 - val_loss: 0.0571 - val_accuracy: 0.9833
# Epoch 17/30
# 54000/54000 [==============================] - 219s 4ms/sample - loss: 0.0445 - accuracy: 0.9857 - val_loss: 0.0640 - val_accuracy: 0.9820
# Epoch 18/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0403 - accuracy: 0.9871 - val_loss: 0.0643 - val_accuracy: 0.9820
# Epoch 19/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0374 - accuracy: 0.9878 - val_loss: 0.0546 - val_accuracy: 0.9840
# Epoch 20/30
# 54000/54000 [==============================] - 195s 4ms/sample - loss: 0.0348 - accuracy: 0.9888 - val_loss: 0.0560 - val_accuracy: 0.9833
# Epoch 21/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0329 - accuracy: 0.9894 - val_loss: 0.0523 - val_accuracy: 0.9865
# Epoch 22/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0299 - accuracy: 0.9903 - val_loss: 0.0594 - val_accuracy: 0.9838
# Epoch 23/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0276 - accuracy: 0.9910 - val_loss: 0.0530 - val_accuracy: 0.9852
# Epoch 24/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.0256 - accuracy: 0.9917 - val_loss: 0.0487 - val_accuracy: 0.9853
# Epoch 25/30
# 54000/54000 [==============================] - 190s 4ms/sample - loss: 0.0239 - accuracy: 0.9927 - val_loss: 0.0532 - val_accuracy: 0.9855
# Epoch 26/30
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0226 - accuracy: 0.9925 - val_loss: 0.0537 - val_accuracy: 0.9860
# Epoch 27/30
# 54000/54000 [==============================] - 193s 4ms/sample - loss: 0.0205 - accuracy: 0.9935 - val_loss: 0.0595 - val_accuracy: 0.9835
# Epoch 28/30
# 54000/54000 [==============================] - 199s 4ms/sample - loss: 0.0182 - accuracy: 0.9946 - val_loss: 0.0531 - val_accuracy: 0.9857
# Epoch 29/30
# 54000/54000 [==============================] - 192s 4ms/sample - loss: 0.0175 - accuracy: 0.9943 - val_loss: 0.0545 - val_accuracy: 0.9870
# Epoch 30/30
# 54000/54000 [==============================] - 197s 4ms/sample - loss: 0.0159 - accuracy: 0.9954 - val_loss: 0.0556 - val_accuracy: 0.9850

# %%
#### EVALUATING THE MODEL

model.evaluate(X_test, Y_test_req, batch_size=32)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.05050676553477242, 0.9847]

# %%
#### PRINTING THE CONFUSION MATRIX

predictions = model.predict_classes(X_test)
print(confusion_matrix(Y_test_cm, predictions))
# Out:
# [[ 971    0    1    0    0    2    2    1    3    0]
#  [   1 1127    1    0    0    1    2    1    2    0]
#  [   4    0 1018    1    1    0    0    3    4    1]
#  [   0    0    2  978    0   20    0    1    7    2]
#  [   0    0    2    0  975    0    2    2    0    1]
#  [   1    0    0    0    1  885    1    0    3    1]
#  [   3    2    0    1    1    6  942    0    3    0]
#  [   0    1    6    2    1    0    0 1014    1    3]
#  [   2    0    1    1    0    5    0    1  962    2]
#  [   1    3    0    7   12    3    0    6    2  975]]

# %% [markdown]
# <h1> RESIDUAL NETWORK - 18 LAYER</h1>

# %%
#### DEFINING THE CONVOLUTION LAYTER

def conv_layer(inputs, filters, stride):
    
    shortcut = inputs
    
    n1, n2 = filters
    
    conv_1 = Conv2D(n1, (3,3), strides=stride, padding='same')(inputs)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Activation('relu')(conv_1)
    
    conv_2 = Conv2D(n2, (3,3), strides=1, padding='same')(conv_1)
    conv_2 = BatchNormalization()(conv_2)
    
    short_cut = Conv2D(n2, (3,3), strides=stride, padding='same')(shortcut)
    short_cut = BatchNormalization()(short_cut)
    
    output = Add()([conv_2, short_cut])
    output = Activation('relu')(output)
    
    return output

# %%
#### DEFINING THE IDENTITY LAYER

def identity_layer(inputs, filters):
    
    shortcut = inputs
    
    n1, n2 = filters
        
    conv_1 = Conv2D(n1, (3,3), strides=1, padding='same')(inputs)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Activation('relu')(conv_1)
    
    conv_2 = Conv2D(n2, (3,3), strides=1, padding='same')(conv_1)
    conv_2 = BatchNormalization()(conv_2)
    
    output = Add()([conv_2, shortcut])
    output = Activation('relu')(output)
    
    return output

# %%
#### DEFINING THE MODEL 

def ResNet18(input_shape, classes):
    
    inputs = Input(input_shape)
    
    layer_1 = ZeroPadding2D((3,3))(inputs)
    
    conv_1 = Conv2D(64, (7,7), strides=2)(layer_1)
    conv_1 = BatchNormalization()(conv_1)
    conv_1 = Activation('relu')(conv_1)
    conv_1 = ZeroPadding2D((1,1))(conv_1)
    conv_1 = MaxPool2D((3,3), strides=2)(conv_1)
    
    conv_2 = conv_layer(conv_1, [64, 64], stride=1)
    conv_2 = identity_layer(conv_2, [64, 64])
    
    conv_3 = conv_layer(conv_2, [128, 128], stride=2)
    conv_3 = identity_layer(conv_3, [128, 128])
    /
    conv_4 = conv_layer(conv_3, [256, 256], stride=2)
    conv_4 = identity_layer(conv_4, [256, 256])
    
    conv_5 = conv_layer(conv_4, [512, 512], stride=2)
    conv_5 = identity_layer(conv_5, [512, 512])
    
    avg_layer = GlobalAveragePooling2D()(conv_5)
    
    output = Dense(classes, activation='softmax')(avg_layer)
    
    model = Model(inputs=inputs, outputs = output)
    
    return model

# %%
#### CALLING THE MODEL

ResNet18 = ResNet18(input_shape=(28, 28, 1), classes=10)

# %%
### MODEL SUMMARY

ResNet18.summary()
# Out:
# Model: "model_11"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_25 (InputLayer)           [(None, 28, 28, 1)]  0
# __________________________________________________________________________________________________
# zero_padding2d_45 (ZeroPadding2 (None, 34, 34, 1)    0           input_25[0][0]
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 14, 14, 64)   3200        zero_padding2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_195 (BatchN (None, 14, 14, 64)   256         conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 14, 14, 64)   0           batch_normalization_195[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_46 (ZeroPadding2 (None, 16, 16, 64)   0           activation_152[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_29 (MaxPooling2D) (None, 7, 7, 64)     0           zero_padding2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_212 (Conv2D)             (None, 7, 7, 64)     36928       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_196 (BatchN (None, 7, 7, 64)     256         conv2d_212[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 7, 7, 64)     0           batch_normalization_196[0][0]
# __________________________________________________________________________________________________
# conv2d_213 (Conv2D)             (None, 7, 7, 64)     36928       activation_153[0][0]
# __________________________________________________________________________________________________
# conv2d_214 (Conv2D)             (None, 7, 7, 64)     36928       max_pooling2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_197 (BatchN (None, 7, 7, 64)     256         conv2d_213[0][0]
# __________________________________________________________________________________________________
# batch_normalization_198 (BatchN (None, 7, 7, 64)     256         conv2d_214[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 7, 7, 64)     0           batch_normalization_197[0][0]
#                                                                  batch_normalization_198[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 7, 7, 64)     0           add_67[0][0]
# __________________________________________________________________________________________________
# conv2d_215 (Conv2D)             (None, 7, 7, 64)     36928       activation_154[0][0]
# __________________________________________________________________________________________________
# batch_normalization_199 (BatchN (None, 7, 7, 64)     256         conv2d_215[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 7, 7, 64)     0           batch_normalization_199[0][0]
# __________________________________________________________________________________________________
# conv2d_216 (Conv2D)             (None, 7, 7, 64)     36928       activation_155[0][0]
# __________________________________________________________________________________________________
# batch_normalization_200 (BatchN (None, 7, 7, 64)     256         conv2d_216[0][0]
# __________________________________________________________________________________________________
# add_68 (Add)                    (None, 7, 7, 64)     0           batch_normalization_200[0][0]
#                                                                  activation_154[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 7, 7, 64)     0           add_68[0][0]
# __________________________________________________________________________________________________
# conv2d_217 (Conv2D)             (None, 4, 4, 128)    73856       activation_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_201 (BatchN (None, 4, 4, 128)    512         conv2d_217[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 4, 4, 128)    0           batch_normalization_201[0][0]
# __________________________________________________________________________________________________
# conv2d_218 (Conv2D)             (None, 4, 4, 128)    147584      activation_157[0][0]
# __________________________________________________________________________________________________
# conv2d_219 (Conv2D)             (None, 4, 4, 128)    73856       activation_156[0][0]
# __________________________________________________________________________________________________
# batch_normalization_202 (BatchN (None, 4, 4, 128)    512         conv2d_218[0][0]
# __________________________________________________________________________________________________
# batch_normalization_203 (BatchN (None, 4, 4, 128)    512         conv2d_219[0][0]
# __________________________________________________________________________________________________
# add_69 (Add)                    (None, 4, 4, 128)    0           batch_normalization_202[0][0]
#                                                                  batch_normalization_203[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 4, 4, 128)    0           add_69[0][0]
# __________________________________________________________________________________________________
# conv2d_220 (Conv2D)             (None, 4, 4, 128)    147584      activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_204 (BatchN (None, 4, 4, 128)    512         conv2d_220[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 4, 4, 128)    0           batch_normalization_204[0][0]
# __________________________________________________________________________________________________
# conv2d_221 (Conv2D)             (None, 4, 4, 128)    147584      activation_159[0][0]
# __________________________________________________________________________________________________
# batch_normalization_205 (BatchN (None, 4, 4, 128)    512         conv2d_221[0][0]
# __________________________________________________________________________________________________
# add_70 (Add)                    (None, 4, 4, 128)    0           batch_normalization_205[0][0]
#                                                                  activation_158[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 4, 4, 128)    0           add_70[0][0]
# __________________________________________________________________________________________________
# conv2d_222 (Conv2D)             (None, 2, 2, 256)    295168      activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_206 (BatchN (None, 2, 2, 256)    1024        conv2d_222[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 2, 2, 256)    0           batch_normalization_206[0][0]
# __________________________________________________________________________________________________
# conv2d_223 (Conv2D)             (None, 2, 2, 256)    590080      activation_161[0][0]
# __________________________________________________________________________________________________
# conv2d_224 (Conv2D)             (None, 2, 2, 256)    295168      activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_207 (BatchN (None, 2, 2, 256)    1024        conv2d_223[0][0]
# __________________________________________________________________________________________________
# batch_normalization_208 (BatchN (None, 2, 2, 256)    1024        conv2d_224[0][0]
# __________________________________________________________________________________________________
# add_71 (Add)                    (None, 2, 2, 256)    0           batch_normalization_207[0][0]
#                                                                  batch_normalization_208[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 2, 2, 256)    0           add_71[0][0]
# __________________________________________________________________________________________________
# conv2d_225 (Conv2D)             (None, 2, 2, 256)    590080      activation_162[0][0]
# __________________________________________________________________________________________________
# batch_normalization_209 (BatchN (None, 2, 2, 256)    1024        conv2d_225[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 2, 2, 256)    0           batch_normalization_209[0][0]
# __________________________________________________________________________________________________
# conv2d_226 (Conv2D)             (None, 2, 2, 256)    590080      activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_210 (BatchN (None, 2, 2, 256)    1024        conv2d_226[0][0]
# __________________________________________________________________________________________________
# add_72 (Add)                    (None, 2, 2, 256)    0           batch_normalization_210[0][0]
#                                                                  activation_162[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 2, 2, 256)    0           add_72[0][0]
# __________________________________________________________________________________________________
# conv2d_227 (Conv2D)             (None, 1, 1, 512)    1180160     activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_211 (BatchN (None, 1, 1, 512)    2048        conv2d_227[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 1, 1, 512)    0           batch_normalization_211[0][0]
# __________________________________________________________________________________________________
# conv2d_228 (Conv2D)             (None, 1, 1, 512)    2359808     activation_165[0][0]
# __________________________________________________________________________________________________
# conv2d_229 (Conv2D)             (None, 1, 1, 512)    1180160     activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_212 (BatchN (None, 1, 1, 512)    2048        conv2d_228[0][0]
# __________________________________________________________________________________________________
# batch_normalization_213 (BatchN (None, 1, 1, 512)    2048        conv2d_229[0][0]
# __________________________________________________________________________________________________
# add_73 (Add)                    (None, 1, 1, 512)    0           batch_normalization_212[0][0]
#                                                                  batch_normalization_213[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 1, 1, 512)    0           add_73[0][0]
# __________________________________________________________________________________________________
# conv2d_230 (Conv2D)             (None, 1, 1, 512)    2359808     activation_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_214 (BatchN (None, 1, 1, 512)    2048        conv2d_230[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 1, 1, 512)    0           batch_normalization_214[0][0]
# __________________________________________________________________________________________________
# conv2d_231 (Conv2D)             (None, 1, 1, 512)    2359808     activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_215 (BatchN (None, 1, 1, 512)    2048        conv2d_231[0][0]
# __________________________________________________________________________________________________
# add_74 (Add)                    (None, 1, 1, 512)    0           batch_normalization_215[0][0]
#                                                                  activation_166[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 1, 1, 512)    0           add_74[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_4 (Glo (None, 512)          0           activation_168[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 10)           5130        global_average_pooling2d_4[0][0]
# ==================================================================================================
# Total params: 12,603,210
# Trainable params: 12,593,482
# Non-trainable params: 9,728
# __________________________________________________________________________________________________

# %%
#### COMPILING THE MODEL

opt = SGD(lr=1e-4, momentum=0.9)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
#### FITTING THE MODEL

model.fit(X_train, Y_train_req, epochs=20, batch_size=32, validation_split=0.1)
# Out:
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/20
# 54000/54000 [==============================] - 118s 2ms/sample - loss: 0.2384 - accuracy: 0.9246 - val_loss: 0.0675 - val_accuracy: 0.9797
# Epoch 2/20
# 54000/54000 [==============================] - 138s 3ms/sample - loss: 0.0691 - accuracy: 0.9782 - val_loss: 0.0575 - val_accuracy: 0.9832
# Epoch 3/20
# 54000/54000 [==============================] - 191s 4ms/sample - loss: 0.0428 - accuracy: 0.9859 - val_loss: 0.0473 - val_accuracy: 0.9858
# Epoch 4/20
# 54000/54000 [==============================] - 213s 4ms/sample - loss: 0.0285 - accuracy: 0.9911 - val_loss: 0.0467 - val_accuracy: 0.9865
# Epoch 5/20
# 54000/54000 [==============================] - 189s 4ms/sample - loss: 0.0176 - accuracy: 0.9949 - val_loss: 0.0447 - val_accuracy: 0.9870
# Epoch 6/20
# 54000/54000 [==============================] - 188s 3ms/sample - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.0436 - val_accuracy: 0.9878
# Epoch 7/20
# 54000/54000 [==============================] - 213s 4ms/sample - loss: 0.0103 - accuracy: 0.9973 - val_loss: 0.0425 - val_accuracy: 0.9888
# Epoch 8/20
# 54000/54000 [==============================] - 252s 5ms/sample - loss: 0.0080 - accuracy: 0.9982 - val_loss: 0.0425 - val_accuracy: 0.9878
# Epoch 9/20
# 54000/54000 [==============================] - 240s 4ms/sample - loss: 0.0066 - accuracy: 0.9986 - val_loss: 0.0414 - val_accuracy: 0.9885
# Epoch 10/20
# 54000/54000 [==============================] - 262s 5ms/sample - loss: 0.0053 - accuracy: 0.9990 - val_loss: 0.0427 - val_accuracy: 0.9885
# Epoch 11/20
# 54000/54000 [==============================] - 264s 5ms/sample - loss: 0.0046 - accuracy: 0.9991 - val_loss: 0.0420 - val_accuracy: 0.9897
# Epoch 12/20
# 54000/54000 [==============================] - 274s 5ms/sample - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0405 - val_accuracy: 0.9897
# Epoch 13/20
# 54000/54000 [==============================] - 280s 5ms/sample - loss: 0.0035 - accuracy: 0.9993 - val_loss: 0.0414 - val_accuracy: 0.9892
# Epoch 14/20
# 54000/54000 [==============================] - 280s 5ms/sample - loss: 0.0030 - accuracy: 0.9996 - val_loss: 0.0407 - val_accuracy: 0.9893
# Epoch 15/20
# 54000/54000 [==============================] - 355s 7ms/sample - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.0431 - val_accuracy: 0.9895
# Epoch 16/20
# 54000/54000 [==============================] - 386s 7ms/sample - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.0412 - val_accuracy: 0.9893
# Epoch 17/20
# 54000/54000 [==============================] - 422s 8ms/sample - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0401 - val_accuracy: 0.9890
# Epoch 18/20
# 54000/54000 [==============================] - 391s 7ms/sample - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0435 - val_accuracy: 0.9902
# Epoch 19/20
# 54000/54000 [==============================] - 409s 8ms/sample - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0429 - val_accuracy: 0.9897
# Epoch 20/20
# 54000/54000 [==============================] - 362s 7ms/sample - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.0416 - val_accuracy: 0.9893

# %%
#### EVALUATING THE MODEL

model.evaluate(X_test, Y_test_req, batch_size=32)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.03895506707870809, 0.9904]
